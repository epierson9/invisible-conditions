# %%
# %load_ext autoreload 
# %autoreload 2
import pandas as pd
from tqdm.notebook import tqdm
import os
import json
import pickle

from mimic_helper_fs import get_icd_code_long_title
from mimic_helper_fs import get_icd_codes_with_prefix
from mimic_helper_fs import get_ids_with_icd_codes, get_ids_with_kws
from mimic_helper_fs import get_coocurring_symptoms_codes, get_coocurring_symptoms_kws
from mimic_paths import ed_path, hosp_path, admissions_path, patients_path

from ipv_codes import SUSPICIOUS_SYMPTOMS_ICD_CODES_PREFIXES,SUSPICIOUS_SYMPTOMS_ICD_CODES

pd.set_option('max_rows', 500)
pd.set_option('display.width', 500)
pd.set_option('display.max_colwidth', 80)

# %% [markdown]
# # Load data

# %%
english_names = pd.read_csv(hosp_path + 'd_icd_diagnoses.csv.gz')
ed_diagnoses = pd.read_csv(ed_path + 'diagnosis.csv.gz')
hosp_diagnoses = pd.read_csv(hosp_path + 'diagnoses_icd.csv.gz')

all_hosp_subject_ids = list(hosp_diagnoses['subject_id'])
all_ed_subject_ids = list(ed_diagnoses['subject_id'])
all_subject_ids = list(set(all_ed_subject_ids + all_hosp_subject_ids))
diagnoses = hosp_diagnoses

# %%
english_names[english_names['icd_code'].str.startswith('Z6')]
# Out:
#        icd_code  icd_version                                                                       long_title
# 108908      Z60           10                                           Problems related to social environment
# 108909     Z600           10                                 Problems of adjustment to life-cycle transitions
# 108910     Z602           10                                                 Problems related to living alone
# 108911     Z603           10                                                         Acculturation difficulty
# 108912     Z604           10                                                   Social exclusion and rejection
# 108913     Z605           10                     Target of (perceived) adverse discrimination and persecution
# 108914     Z608           10                                     Other problems related to social environment
# 108915     Z609           10                               Problem related to social environment, unspecified
# 108916      Z62           10                                                   Problems related to upbringing
# 108917     Z620           10                                      Inadequate parental supervision and control
# 108918     Z621           10                                                          Parental overprotection
# 108919     Z622           10                                                     Upbringing away from parents
# 108920    Z6221           10                                                         Child in welfare custody
# 108921    Z6222           10                                                         Institutional upbringing
# 108922    Z6229           10                                               Other upbringing away from parents
# 108923     Z623           10                                      Hostility towards and scapegoating of child
# 108924     Z626           10                                      Inappropriate (excessive) parental pressure
# 108925     Z628           10                                   Other specified problems related to upbringing
# 108926    Z6281           10                                           Personal history of abuse in childhood
# 108927   Z62810           10                       Personal history of physical and sexual abuse in childhood
# 108928   Z62811           10                             Personal history of psychological abuse in childhood
# 108929   Z62812           10                                         Personal history of neglect in childhood
# 108930   Z62813           10             Personal history of forced labor or sexual exploitation in childhood
# 108931   Z62819           10                               Personal history of unspecified abuse in childhood
# 108932    Z6282           10                                                            Parent-child conflict
# 108933   Z62820           10                                                 Parent-biological child conflict
# 108934   Z62821           10                                                    Parent-adopted child conflict
# 108935   Z62822           10                                                     Parent-foster child conflict
# 108936    Z6289           10                                   Other specified problems related to upbringing
# 108937   Z62890           10                                                    Parent-child estrangement NEC
# 108938   Z62891           10                                                                  Sibling rivalry
# 108939   Z62898           10                                   Other specified problems related to upbringing
# 108940     Z629           10                                       Problem related to upbringing, unspecified
# 108941      Z63           10  Other problems related to primary support group, including family circumstances
# 108942     Z630           10                                  Problems in relationship with spouse or partner
# 108943     Z631           10                                            Problems in relationship with in-laws
# 108944     Z633           10                                                         Absence of family member
# 108945    Z6331           10                              Absence of family member due to military deployment
# 108946    Z6332           10                                                   Other absence of family member
# 108947     Z634           10                                         Disappearance and death of family member
# 108948     Z635           10                                   Disruption of family by separation and divorce
# 108949     Z636           10                                          Dependent relative needing care at home
# 108950     Z637           10                       Other stressful life events affecting family and household
# 108951    Z6371           10         Stress on family due to return of family member from military deployment
# 108952    Z6372           10                                          Alcoholism and drug addiction in family
# 108953    Z6379           10                       Other stressful life events affecting family and household
# 108954     Z638           10                        Other specified problems related to primary support group
# 108955     Z639           10                            Problem related to primary support group, unspecified
# 108956      Z64           10                           Problems related to certain psychosocial circumstances
# 108957     Z640           10                                           Problems related to unwanted pregnancy
# 108958     Z641           10                                                  Problems related to multiparity
# 108959     Z644           10                                                          Discord with counselors
# 108960      Z65           10                             Problems related to other psychosocial circumstances
# 108961     Z650           10                Conviction in civil and criminal proceedings without imprisonment
# 108962     Z651           10                                             Imprisonment and other incarceration
# 108963     Z652           10                                          Problems related to release from prison
# 108964     Z653           10                                    Problems related to other legal circumstances
# 108965     Z654           10                                                    Victim of crime and terrorism
# 108966     Z655           10                                  Exposure to disaster, war and other hostilities
# 108967     Z658           10                   Other specified problems related to psychosocial circumstances
# 108968     Z659           10                        Problem related to unspecified psychosocial circumstances
# 108969      Z66           10                                                               Do not resuscitate
# 108970      Z67           10                                                                       Blood type
# 108971     Z671           10                                                                     Type A blood
# 108972    Z6710           10                                                        Type A blood, Rh positive
# 108973    Z6711           10                                                        Type A blood, Rh negative
# 108974     Z672           10                                                                     Type B blood
# 108975    Z6720           10                                                        Type B blood, Rh positive
# 108976    Z6721           10                                                        Type B blood, Rh negative
# 108977     Z673           10                                                                    Type AB blood
# 108978    Z6730           10                                                       Type AB blood, Rh positive
# 108979    Z6731           10                                                       Type AB blood, Rh negative
# 108980     Z674           10                                                                     Type O blood
# 108981    Z6740           10                                                        Type O blood, Rh positive
# 108982    Z6741           10                                                        Type O blood, Rh negative
# 108983     Z679           10                                                           Unspecified blood type
# 108984    Z6790           10                                              Unspecified blood type, Rh positive
# 108985    Z6791           10                                              Unspecified blood type, Rh negative
# 108986      Z68           10                                                            Body mass index [BMI]
# 108987     Z681           10                                        Body mass index (BMI) 19.9 or less, adult
# 108988     Z682           10                                               Body mass index (BMI) 20-29, adult
# 108989    Z6820           10                                           Body mass index (BMI) 20.0-20.9, adult
# 108990    Z6821           10                                           Body mass index (BMI) 21.0-21.9, adult
# 108991    Z6822           10                                           Body mass index (BMI) 22.0-22.9, adult
# 108992    Z6823           10                                           Body mass index (BMI) 23.0-23.9, adult
# 108993    Z6824           10                                           Body mass index (BMI) 24.0-24.9, adult
# 108994    Z6825           10                                           Body mass index (BMI) 25.0-25.9, adult
# 108995    Z6826           10                                           Body mass index (BMI) 26.0-26.9, adult
# 108996    Z6827           10                                           Body mass index (BMI) 27.0-27.9, adult
# 108997    Z6828           10                                           Body mass index (BMI) 28.0-28.9, adult
# 108998    Z6829           10                                           Body mass index (BMI) 29.0-29.9, adult
# 108999     Z683           10                                               Body mass index (BMI) 30-39, adult
# 109000    Z6830           10                                           Body mass index (BMI) 30.0-30.9, adult
# 109001    Z6831           10                                           Body mass index (BMI) 31.0-31.9, adult
# 109002    Z6832           10                                           Body mass index (BMI) 32.0-32.9, adult
# 109003    Z6833           10                                           Body mass index (BMI) 33.0-33.9, adult
# 109004    Z6834           10                                           Body mass index (BMI) 34.0-34.9, adult
# 109005    Z6835           10                                           Body mass index (BMI) 35.0-35.9, adult
# 109006    Z6836           10                                           Body mass index (BMI) 36.0-36.9, adult
# 109007    Z6837           10                                           Body mass index (BMI) 37.0-37.9, adult
# 109008    Z6838           10                                           Body mass index (BMI) 38.0-38.9, adult
# 109009    Z6839           10                                           Body mass index (BMI) 39.0-39.9, adult
# 109010     Z684           10                                       Body mass index (BMI) 40 or greater, adult
# 109011    Z6841           10                                           Body mass index (BMI) 40.0-44.9, adult
# 109012    Z6842           10                                           Body mass index (BMI) 45.0-49.9, adult
# 109013    Z6843           10                                           Body mass index (BMI) 50.0-59.9, adult
# 109014    Z6844           10                                           Body mass index (BMI) 60.0-69.9, adult
# 109015    Z6845           10                                       Body mass index (BMI) 70 or greater, adult
# 109016     Z685           10                                                  Body mass index (BMI) pediatric
# 109017    Z6851           10                Body mass index (BMI) pediatric, less than 5th percentile for age
# 109018    Z6852           10  Body mass index (BMI) pediatric, 5th percentile to less than 85th percentile...
# 109019    Z6853           10  Body mass index (BMI) pediatric, 85th percentile to less than 95th percentil...
# 109020    Z6854           10  Body mass index (BMI) pediatric, greater than or equal to 95th percentile fo...
# 109021      Z69           10         Encounter for mental health services for victim and perpetrator of abuse
# 109022     Z690           10                    Encounter for mental health services for child abuse problems
# 109023    Z6901           10                    Encounter for mental health services for parental child abuse
# 109024   Z69010           10          Encounter for mental health services for victim of parental child abuse
# 109025   Z69011           10     Encounter for mental health services for perpetrator of parental child abuse
# 109026    Z6902           10                Encounter for mental health services for non-parental child abuse
# 109027   Z69020           10      Encounter for mental health services for victim of non-parental child abuse
# 109028   Z69021           10  Encounter for mental health services for perpetrator of non-parental child a...
# 109029     Z691           10       Encounter for mental health services for spousal or partner abuse problems
# 109030    Z6911           10      Encounter for mental health services for victim of spousal or partner abuse
# 109031    Z6912           10  Encounter for mental health services for perpetrator of spousal or partner a...
# 109032     Z698           10    Encounter for mental health services for victim or perpetrator of other abuse
# 109033    Z6981           10                   Encounter for mental health services for victim of other abuse
# 109034    Z6982           10              Encounter for mental health services for perpetrator of other abuse

# %%
len(set(ed_diagnoses[ed_diagnoses['icd_code'].str.startswith('Z')]['stay_id']))
# Out:
# 21357

# %%
sdoh_z_codes = ['Z55', 'Z56', 'Z57', 'Z58', 'Z59', 'Z60', 'Z61', 'Z62', 'Z63', 'Z64', 'Z65']
for z_code_prefix in sdoh_z_codes:
    print(len(set(ed_diagnoses[ed_diagnoses['icd_code'].str.startswith(z_code_prefix)]['stay_id'])))
# Out:
# 0
# 1
# 4
# 0
# 918
# 3
# 0
# 1
# 40
# 0
# 0

# %%
# Filter for patients admitted to the hospital after the ED; these are the patients
# we have demographic information for. 
ed_admitted_patients = list(admissions[admissions['admission_location'] == 'EMERGENCY ROOM']['hadm_id'])

admissions = pd.read_csv(admissions_path)
patients = pd.read_csv(patients_path)

sid_gender_map = dict(zip(patients.subject_id, patients.gender))
sid_age_map = dict(zip(patients.subject_id, patients.anchor_age))
sid_ethnicity_map = dict(zip(admissions.subject_id, admissions.ethnicity))
sid_marital_status_map = dict(zip(admissions.subject_id, admissions.marital_status))
sid_insurance_map = dict(zip(admissions.subject_id, admissions.insurance))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7dd9581922e7> in <module>
#       1 # Filter for patients admitted to the hospital after the ED; these are the patients
#       2 # we have demographic information for.
# ----> 3 ed_admitted_patients = list(admissions[admissions['admission_location'] == 'EMERGENCY ROOM']['hadm_id'])
#       4
#       5 admissions = pd.read_csv(admissions_path)
#
# NameError: name 'admissions' is not defined

# %%
diagnoses['anchor_age'] = diagnoses['subject_id'].map(sid_age_map)
diagnoses['gender'] = diagnoses['subject_id'].map(sid_gender_map)
diagnoses['ethnicity'] = diagnoses['subject_id'].map(sid_ethnicity_map)
diagnoses['marital_status'] = diagnoses['subject_id'].map(sid_marital_status_map)
diagnoses['insurance'] = diagnoses['subject_id'].map(sid_insurance_map)

# %%
# Filter out men and children
# diagnoses = diagnoses[diagnoses['gender'] == 'F']
diagnoses = diagnoses[diagnoses['anchor_age'] > 18]
# diagnoses = diagnoses[diagnoses['hadm_id'].isin(ed_admitted_patients)]

# %%
# Number of subjects
n_admissions = len(set(diagnoses['hadm_id']))
print("# of Admissions: ", n_admissions)

# %% [markdown]
# # Print counts and prevalence of *any* symptom

# %%
diagnoses = pd.merge(diagnoses, english_names, on=['icd_code', 'icd_version'])

# %%
diagnosis_counts = pd.DataFrame(diagnoses['icd_code'].value_counts().reset_index())
diagnosis_counts = diagnosis_counts.rename(columns={'icd_code': 'counts', 'index': 'icd_code'})
diagnosis_counts['prevalence'] = diagnosis_counts['counts']/n_admissions

# %%
code_name_map = dict(zip(english_names.icd_code, english_names.long_title))
diagnosis_counts['long_title'] = diagnosis_counts['icd_code'].map(code_name_map)

# %%
most_popular_codes_50 = list(diagnosis_counts.head(50)['icd_code'])
with open('./most_popular_codes_50.ob', 'wb') as fp:
    pickle.dump(most_popular_codes_50, fp)
diagnosis_counts.head(50)
# Out:
#    icd_code  counts  prevalence                                                                       long_title
# 0      4019  104051    0.227408                                               Unspecified essential hypertension
# 1      2724   68207    0.149069                                             Other and unspecified hyperlipidemia
# 2       I10   54687    0.119521                                                 Essential (primary) hypertension
# 3      E785   51091    0.111662                                                      Hyperlipidemia, unspecified
# 4     53081   49462    0.108101                                                                Esophageal reflux
# 5     25000   43702    0.095513  Diabetes mellitus without mention of complication, type II or unspecified ty...
# 6    Z87891   40782    0.089131                                          Personal history of nicotine dependence
# 7     42731   37335    0.081597                                                              Atrial fibrillation
# 8      4280   36875    0.080592                                            Congestive heart failure, unspecified
# 9       311   36706    0.080223                                    Depressive disorder, not elsewhere classified
# 10    41401   36404    0.079563                               Coronary atherosclerosis of native coronary artery
# 11     K219   35587    0.077777                             Gastro-esophageal reflux disease without esophagitis
# 12    V1582   32218    0.070414                                                  Personal history of tobacco use
# 13     F329   30226    0.066060                           Major depressive disorder, single episode, unspecified
# 14     5849   29261    0.063951                                                Acute kidney failure, unspecified
# 15     2449   29031    0.063449                                              Unspecified acquired hypothyroidism
# 16    I2510   26705    0.058365  Atherosclerotic heart disease of native coronary artery without angina pectoris
# 17     3051   26271    0.057416                                                             Tobacco use disorder
# 18     2859   24586    0.053734                                                              Anemia, unspecified
# 19    40390   24032    0.052523  Hypertensive chronic kidney disease, unspecified, with chronic kidney diseas...
# 20     F419   23878    0.052186                                                    Anxiety disorder, unspecified
# 21    V5861   22785    0.049798                                        Long-term (current) use of anticoagulants
# 22    30000   22632    0.049463                                                       Anxiety state, unspecified
# 23     N179   21204    0.046342                                                Acute kidney failure, unspecified
# 24     5990   20540    0.044891                                      Urinary tract infection, site not specified
# 25     2720   20180    0.044104                                                        Pure hypercholesterolemia
# 26    49390   20036    0.043790                                            Asthma, unspecified type, unspecified
# 27    V5867   19754    0.043173                                               Long-term (current) use of insulin
# 28     Z794   18327    0.040054                                               Long term (current) use of insulin
# 29     E039   18055    0.039460                                                      Hypothyroidism, unspecified
# 30     5859   18040    0.039427                                              Chronic kidney disease, unspecified
# 31    32723   17869    0.039053                                       Obstructive sleep apnea (adult)(pediatric)
# 32    Z7901   17733    0.038756                                        Long term (current) use of anticoagulants
# 33     E119   17601    0.038468                                   Type 2 diabetes mellitus without complications
# 34    V4582   15678    0.034265                            Percutaneous transluminal coronary angioplasty status
# 35     Y929   15572    0.034033                                              Unspecified place or not applicable
# 36   F17210   15493    0.033861                                   Nicotine dependence, cigarettes, uncomplicated
# 37      412   15355    0.033559                                                        Old myocardial infarction
# 38      496   14672    0.032066                             Chronic airway obstruction, not elsewhere classified
# 39    V5866   14593    0.031894                                               Long-term (current) use of aspirin
# 40    G4733   14530    0.031756                                      Obstructive sleep apnea (adult) (pediatric)
# 41    27800   14495    0.031679                                                             Obesity, unspecified
# 42     E669   14253    0.031151                                                             Obesity, unspecified
# 43    I4891   14020    0.030641                                                  Unspecified atrial fibrillation
# 44     D649   13953    0.030495                                                              Anemia, unspecified
# 45    V4581   13640    0.029811                                                      Aortocoronary bypass status
# 46   J45909   13636    0.029802                                                Unspecified asthma, uncomplicated
# 47    Z7902   13488    0.029479                         Long term (current) use of antithrombotics/antiplatelets
# 48     2761   12879    0.028148                                                Hyposmolality and/or hyponatremia
# 49    41400   12258    0.026790          Coronary atherosclerosis of unspecified type of vessel, native or graft

# %%
# As you increase the code set, what % of the admissions do they describe?

# %% [markdown]
# # Print counts and prevalence of *suspicious* symptoms

# %%
# NOTE: Each count reflects any code with this *prefix*. This means that the count 
# can include initial encounter, sequela, etc.
id_type = 'hadm_id'
prevalence_dicts = []
for code in tqdm(SUSPICIOUS_SYMPTOMS_ICD_CODES):
    try:
        descr = get_icd_code_long_title(english_names, code)
        n_patients = len(get_ids_with_icd_codes(diagnoses, id_type, [code]))
        p_y = n_patients/len(set(diagnoses[id_type]))
        prevalence_dicts.append({'code': code, 'long_title': descr, 'prevalence': p_y,
                                 'count': n_patients})
    except:
        print(code)
prevalence_df = pd.DataFrame(prevalence_dicts)
prevalence_df.sort_values('prevalence', ascending=False)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#        code                                                                       long_title  prevalence  count
# 4       920                                 Contusion of face, scalp, and neck except eye(s)    0.004524    562
# 0     95901                                                         Head injury, unspecified    0.003147    391
# 1      7842                                         Swelling, mass, or lump in head and neck    0.001883    234
# 3      9100  Abrasion or friction burn of face, neck, and scalp except eye, without menti...    0.001409    175
# 34  S0990XA                                    Unspecified injury of head, initial encounter    0.000732     91
# 31  S0003XA                                            Contusion of scalp, initial encounter    0.000427     53
# 46  S0011XA                 Contusion of right eyelid and periocular area, initial encounter    0.000105     13
# 49  S0012XA                  Contusion of left eyelid and periocular area, initial encounter    0.000097     12
# 6      9947                                                   Asphyxiation and strangulation    0.000072      9
# 28  S0001XA                                             Abrasion of scalp, initial encounter    0.000072      9
# 5      E963                                             Assault by hanging and strangulation    0.000056      7
# 57  S00212A                   Abrasion of left eyelid and periocular area, initial encounter    0.000032      4
# 7   S100XXA                                           Contusion of throat, initial encounter    0.000032      4
# 56   S00212                                      Abrasion of left eyelid and periocular area    0.000032      4
# 88   S00511                                                                  Abrasion of lip    0.000024      3
# 89  S00511A                                               Abrasion of lip, initial encounter    0.000024      3
# 53  S00211A                  Abrasion of right eyelid and periocular area, initial encounter    0.000024      3
# 52   S00211                                     Abrasion of right eyelid and periocular area    0.000024      3
# 96   S00531                                                                 Contusion of lip    0.000024      3
# 97  S00531A                                              Contusion of lip, initial encounter    0.000024      3
# 19  S1091XA                          Abrasion of unspecified part of neck, initial encounter    0.000024      3
# 2      9108  Other and unspecified superficial injury of face, neck, and scalp, without m...    0.000024      3
# 40  S0993XA                                    Unspecified injury of face, initial encounter    0.000016      2
# 43  S0010XA           Contusion of unspecified eyelid and periocular area, initial encounter    0.000008      1
# 37  S0991XA                                     Unspecified injury of ear, initial encounter    0.000008      1
# 32  S0003XD                                         Contusion of scalp, subsequent encounter    0.000008      1
# 50  S0012XD               Contusion of left eyelid and periocular area, subsequent encounter    0.000008      1
# 22  S1093XA                         Contusion of unspecified part of neck, initial encounter    0.000008      1
# 10  S1080XA  Unspecified superficial injury of other specified part of neck, initial enco...    0.000008      1
# 27  S0000XS                                 Unspecified superficial injury of scalp, sequela    0.000000      0
# 79  S00412S                                                    Abrasion of left ear, sequela    0.000000      0
# 78  S00412D                                       Abrasion of left ear, subsequent encounter    0.000000      0
# 77  S00412A                                          Abrasion of left ear, initial encounter    0.000000      0
# 76   S00412                                                             Abrasion of left ear    0.000000      0
# 75  S00411S                                                   Abrasion of right ear, sequela    0.000000      0
# 74  S00411D                                      Abrasion of right ear, subsequent encounter    0.000000      0
# 73  S00411A                                         Abrasion of right ear, initial encounter    0.000000      0
# 81  S00431A                                        Contusion of right ear, initial encounter    0.000000      0
# 72   S00411                                                            Abrasion of right ear    0.000000      0
# 71  S00402S                              Unspecified superficial injury of left ear, sequela    0.000000      0
# 70  S00402D                 Unspecified superficial injury of left ear, subsequent encounter    0.000000      0
# 69  S00402A                    Unspecified superficial injury of left ear, initial encounter    0.000000      0
# 68   S00402                                       Unspecified superficial injury of left ear    0.000000      0
# 67  S00401S                             Unspecified superficial injury of right ear, sequela    0.000000      0
# 66  S00401D                Unspecified superficial injury of right ear, subsequent encounter    0.000000      0
# 80   S00431                                                           Contusion of right ear    0.000000      0
# 83  S00431S                                                  Contusion of right ear, sequela    0.000000      0
# 82  S00431D                                     Contusion of right ear, subsequent encounter    0.000000      0
# 92   S00512                                                          Abrasion of oral cavity    0.000000      0
# 98  S00531D                                           Contusion of lip, subsequent encounter    0.000000      0
# 8   S100XXD                                        Contusion of throat, subsequent encounter    0.000000      0
# 9   S100XXS                                                     Contusion of throat, sequela    0.000000      0
# 95  S00512S                                                 Abrasion of oral cavity, sequela    0.000000      0
# 94  S00512D                                    Abrasion of oral cavity, subsequent encounter    0.000000      0
# 93  S00512A                                       Abrasion of oral cavity, initial encounter    0.000000      0
# 91  S00511S                                                         Abrasion of lip, sequela    0.000000      0
# 64   S00401                                      Unspecified superficial injury of right ear    0.000000      0
# 90  S00511D                                            Abrasion of lip, subsequent encounter    0.000000      0
# 11  S1080XD  Unspecified superficial injury of other specified part of neck, subsequent e...    0.000000      0
# 87  S00432S                                                   Contusion of left ear, sequela    0.000000      0
# 86  S00432D                                      Contusion of left ear, subsequent encounter    0.000000      0
# 85  S00432A                                         Contusion of left ear, initial encounter    0.000000      0
# 84   S00432                                                            Contusion of left ear    0.000000      0
# 65  S00401A                   Unspecified superficial injury of right ear, initial encounter    0.000000      0
# 63  S00219S                      Abrasion of unspecified eyelid and periocular area, sequela    0.000000      0
# 26  S0000XD                    Unspecified superficial injury of scalp, subsequent encounter    0.000000      0
# 36  S0990XS                                              Unspecified injury of head, sequela    0.000000      0
# 20  S1091XD                       Abrasion of unspecified part of neck, subsequent encounter    0.000000      0
# 42  S0993XS                                              Unspecified injury of face, sequela    0.000000      0
# 41  S0993XD                                 Unspecified injury of face, subsequent encounter    0.000000      0
# 21  S1091XS                                    Abrasion of unspecified part of neck, sequela    0.000000      0
# 39  S0991XS                                               Unspecified injury of ear, sequela    0.000000      0
# 38  S0991XD                                  Unspecified injury of ear, subsequent encounter    0.000000      0
# 35  S0990XD                                 Unspecified injury of head, subsequent encounter    0.000000      0
# 45  S0010XS                     Contusion of unspecified eyelid and periocular area, sequela    0.000000      0
# 23  S1093XD                      Contusion of unspecified part of neck, subsequent encounter    0.000000      0
# 33  S0003XS                                                      Contusion of scalp, sequela    0.000000      0
# 24  S1093XS                                   Contusion of unspecified part of neck, sequela    0.000000      0
# 25  S0000XA                       Unspecified superficial injury of scalp, initial encounter    0.000000      0
# 30  S0001XS                                                       Abrasion of scalp, sequela    0.000000      0
# 29  S0001XD                                          Abrasion of scalp, subsequent encounter    0.000000      0
# 44  S0010XD        Contusion of unspecified eyelid and periocular area, subsequent encounter    0.000000      0
# 18  S1090XS              Unspecified superficial injury of unspecified part of neck, sequela    0.000000      0
# 62  S00219D         Abrasion of unspecified eyelid and periocular area, subsequent encounter    0.000000      0
# 55  S00211S                            Abrasion of right eyelid and periocular area, sequela    0.000000      0
# 61  S00219A            Abrasion of unspecified eyelid and periocular area, initial encounter    0.000000      0
# 60   S00219                               Abrasion of unspecified eyelid and periocular area    0.000000      0
# 59  S00212S                             Abrasion of left eyelid and periocular area, sequela    0.000000      0
# 58  S00212D                Abrasion of left eyelid and periocular area, subsequent encounter    0.000000      0
# 12  S1080XS          Unspecified superficial injury of other specified part of neck, sequela    0.000000      0
# 13  S1081XA                      Abrasion of other specified part of neck, initial encounter    0.000000      0
# 54  S00211D               Abrasion of right eyelid and periocular area, subsequent encounter    0.000000      0
# 47  S0011XD              Contusion of right eyelid and periocular area, subsequent encounter    0.000000      0
# 14  S1081XD                   Abrasion of other specified part of neck, subsequent encounter    0.000000      0
# 15  S1081XS                                Abrasion of other specified part of neck, sequela    0.000000      0
# 51  S0012XS                            Contusion of left eyelid and periocular area, sequela    0.000000      0
# 16  S1090XA    Unspecified superficial injury of unspecified part of neck, initial encounter    0.000000      0
# 17  S1090XD  Unspecified superficial injury of unspecified part of neck, subsequent encou...    0.000000      0
# 48  S0011XS                           Contusion of right eyelid and periocular area, sequela    0.000000      0
# 99  S00531S                                                        Contusion of lip, sequela    0.000000      0

# %%
# % of patients with suspicious codes
suspicious_hadm_ids = get_ids_with_icd_codes(diagnoses, id_type, SUSPICIOUS_SYMPTOMS_ICD_CODES)
n_with_suspicious_codes = len(suspicious_hadm_ids)
n_subjects = len(all_subject_ids)

print("% Suspicious patients: ", n_with_suspicious_codes/n_subjects)
print("# Suspicious patients: ", n_with_suspicious_codes)
# Out:
# % Suspicious patients:  0.004435341313831077
# # Suspicious patients:  1518

# %%
all_codes = []
for code in SUSPICIOUS_SYMPTOMS_ICD_CODES_PREFIXES:
    
    codes = get_icd_codes_with_prefix(english_names, code)
    all_codes.extend(codes)
SUSPICIOUS_SYMPTOMS_ICD_CODES = all_codes
json.dumps(all_codes)
# Out:
# '["95901", "7842", "9108", "9100", "920", "E963", "9947", "S100XXA", "S100XXD", "S100XXS", "S1080XA", "S1080XD", "S1080XS", "S1081XA", "S1081XD", "S1081XS", "S1090XA", "S1090XD", "S1090XS", "S1091XA", "S1091XD", "S1091XS", "S1093XA", "S1093XD", "S1093XS", "S0000XA", "S0000XD", "S0000XS", "S0001XA", "S0001XD", "S0001XS", "S0003XA", "S0003XD", "S0003XS", "S0990XA", "S0990XD", "S0990XS", "S0991XA", "S0991XD", "S0991XS", "S0993XA", "S0993XD", "S0993XS", "S0010XA", "S0010XD", "S0010XS", "S0011XA", "S0011XD", "S0011XS", "S0012XA", "S0012XD", "S0012XS", "S00211", "S00211A", "S00211D", "S00211S", "S00212", "S00212A", "S00212D", "S00212S", "S00219", "S00219A", "S00219D", "S00219S", "S00401", "S00401A", "S00401D", "S00401S", "S00402", "S00402A", "S00402D", "S00402S", "S00411", "S00411A", "S00411D", "S00411S", "S00412", "S00412A", "S00412D", "S00412S", "S00431", "S00431A", "S00431D", "S00431S", "S00432", "S00432A", "S00432D", "S00432S", "S00511", "S00511A", "S00511D", "S00511S", "S00512", "S00512A", "S00512D", "S00512S", "S00531", "S00531A", "S00531D", "S00531S"]'

# %%
len(code_prefixes), len(all_codes)
# Out:
# (20, 26)

# %%
from ipv_codes import GOLD_STANDARD_IPV_CODES_4, Y_CODES
code_prefixes = GOLD_STANDARD_IPV_CODES_4 + Y_CODES
all_codes = []
for code in code_prefixes:
    
    codes = get_icd_codes_with_prefix(english_names, code)
    all_codes.extend(codes)
json.dumps(all_codes)
# Out:
# '["E9672", "E9673", "E9671", "E9670", "V6111", "99581", "T7411XA", "T7411XD", "T7411XS", "T7491XA", "T7491XD", "T7491XS", "T7611", "T7611XA", "T7611XD", "T7611XS", "T7611XA", "T7611XD", "T7611XS", "T7692", "T7692XA", "T7692XD", "T7692XS", "T7692XA", "T7692XD", "T7692XS"]'

# %%
print("# of ICD Codes total: ", len(set(english_names['icd_code'])))
print("# of ICD Codes in hospital: ", len(set(diagnoses['icd_code'])))

code_counts =  diagnoses.value_counts("icd_code")
code_counts = code_counts.reset_index()
print("# of ICD Codes appearing more than 10 times: ", len(code_counts[code_counts[0] >= 10]))
# Out:
# # of ICD Codes total:  109282
# # of ICD Codes in hospital:  15699
# # of ICD Codes appearing more than 10 times:  5544

# %%
valid_codes = list(code_counts[code_counts[0] >= 10]['icd_code']) 
valid_codes = sorted(list(set(valid_codes)))

# %%
with open('./valid_codes.ob', 'wb') as fp:
    pickle.dump(valid_codes, fp)

# %%
valid_code_str = json.dumps(valid_codes)

# %% [markdown]
# # Group-specific numbers

# %%
# How many suspicious patients in each ethnic group? 
# How many supsicious patients in each insurance group?
# How many suspicious patients in each age group?
set(diagnoses['ethnicity'])
# Out:
# {'AMERICAN INDIAN/ALASKA NATIVE',
#  'ASIAN',
#  'BLACK/AFRICAN AMERICAN',
#  'HISPANIC/LATINO',
#  'OTHER',
#  'UNABLE TO OBTAIN',
#  'UNKNOWN',
#  'WHITE'}

# %%
married = diagnoses[diagnoses['marital_status'] == 'MARRIED']
single = diagnoses[diagnoses['marital_status'] == 'SINGLE']

subsets = [(married, 'Married'), (single, 'Single')]
for group, group_name in subsets:
    n_suspicious_hadm_ids = len(get_ids_with_icd_codes(group, id_type, SUSPICIOUS_SYMPTOMS_ICD_CODES))
    print("Group Name: ", group_name, "\t# Suspicious: ", n_suspicious_hadm_ids)
# Out:
# Group Name:  Married 	# Suspicious:  333
# Group Name:  Single 	# Suspicious:  671

# %%
black = diagnoses[diagnoses['ethnicity'] == 'BLACK/AFRICAN AMERICAN']
white = diagnoses[diagnoses['ethnicity'] == 'WHITE']

subsets = [(black, 'Black'), (white, 'White')]
for group, group_name in subsets:
    n_suspicious_hadm_ids = len(get_ids_with_icd_codes(group, id_type, SUSPICIOUS_SYMPTOMS_ICD_CODES))
    print("Group Name: ", group_name, "\t# Suspicious: ", n_suspicious_hadm_ids)
# Out:
# Group Name:  Black 	# Suspicious:  232
# Group Name:  White 	# Suspicious:  1055

# %%
married = diagnoses[diagnoses['marital_status'] == 'MARRIED']
single = diagnoses[diagnoses['marital_status'] == 'SINGLE']

subsets = [(married, 'Married'), (single, 'Single')]
for group, group_name in subsets:
    n_suspicious_hadm_ids = len(get_ids_with_icd_codes(group, id_type, ['920']))
    print("Group Name: ", group_name, "\t# Suspicious: ", n_suspicious_hadm_ids)
# Out:
# Group Name:  Married 	# Suspicious:  122
# Group Name:  Single 	# Suspicious:  201

# %%
black = diagnoses[diagnoses['ethnicity'] == 'BLACK/AFRICAN AMERICAN']
white = diagnoses[diagnoses['ethnicity'] == 'WHITE']

subsets = [(black, 'Black'), (white, 'White')]
for group, group_name in subsets:
    n_suspicious_hadm_ids = len(get_ids_with_icd_codes(group, id_type, ['920']))
    print("Group Name: ", group_name, "\t# Suspicious: ", n_suspicious_hadm_ids)
# Out:
# Group Name:  Black 	# Suspicious:  53
# Group Name:  White 	# Suspicious:  419
